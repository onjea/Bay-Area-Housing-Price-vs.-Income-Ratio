# %% [markdown]
# ## Bay Area Housing Affordability from 2014 to 2018
#
# ### <font color='green'>DATA SOURCE:</font>
#
# <font color='navy'>Zillow:</font> HOUSING COST data <br>
# https://www.zillow.com/research/data/ <br>
#
# ==> csv file : Mortgage affordability, PRICE-TO-INCOME RATIO
#
# ### <font color='green'>What is the price-to-income ratio?</font>
#
# "**The rule of thumb long used by real estate agents and homebuyers is that you can afford a house if its price is equivalent to roughly 2.6 years of your household income.** That ratio is based on historical nationwide averages under healthy economic conditions. But today, in many places around the country—particularly in coastal cities in California and along the New York–Boston–Washington corridor—housing has become staggeringly more expensive than that."
#
# ==> (quote from citylab.com)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline
plt.rcParams["figure.figsize"] = [19, 9]

ha_df_us = [3.14, 3.15, 3.15, 3.15, 3.16, 3.18, 3.19, 3.2, 3.22, 3.26, 3.30, 3.32, 3.33, 3.36, 3.37, 3.38, 3.44, 3.47, 3.5, 3.54]
ha_df_sf = [8.10, 8.06, 8.06, 8.18, 8.35, 8.56, 8.6, 8.54, 8.53, 8.5, 8.47, 8.53, 8.56, 8.56, 8.55, 8.62, 8.87, 8.92, 8.98, 8.91]
ha_df_sj = [8.02, 8.02, 8.09, 8.23, 8.45, 8.68, 8.75, 8.68, 8.69, 8.65, 8.60, 8.69, 8.78, 8.76, 9.01, 9.46, 9.99, 10.36, 10.34, 10.08]

plt.plot(ha_df_us);
plt.plot(ha_df_sf);
plt.plot(ha_df_sj);

plt.grid()
plt.title('Bay Area Housing Price-to-Income Ratio',family='serif', fontsize=35, color='#0000cc')
ticks_x = np.linspace(0, 20, 21)
ticks_y = np.linspace(2, 12, 6)

plt.xlabel('January 2014 - December 2018', fontsize= 25,family='serif')
plt.ylabel('Price-to-Income Ratio', fontsize= 25,family='serif');

months = [' ', 'June 2014', ' ', ' ', ' ', 'June 2015', ' ', ' ', ' ', 'June 2016', ' ', ' ', ' ','June 2017', ' ', ' ', ' ', 'June 2018', ' ', ' ']
plt.xticks(ticks_x, months, fontsize=18);
plt.yticks(ticks_y);

plt.text(6, 0,'San Jose',fontsize = 15,backgroundcolor = 'green',color = 'white'); # x and y position of start of text
plt.text(3, 0,'San Francisco',fontsize = 15,backgroundcolor = 'orange',color = 'white'); # x and y position of start of text
plt.text(0, 0,'United States',fontsize = 15,backgroundcolor = 'blue',color = 'white'); # x and y position of start of text
